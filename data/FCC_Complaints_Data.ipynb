# %%
from pathlib import Path
import csv
import numpy as np
import pandas as pd
import json

path = Path('..\data\ComplaintsData.json')
with open(path) as f:
    data = json.load(f)

print(data)
# Out:
#  "84660"}'}, ':@computed_region_5ic8_3ue4': '13'}, {'id': '143370', 'ticket_created': '2015-02-21T05:56:08.000Z', 'date_created': '2015-02-21T00:56:08.000', 'issue_type': 'Phone', 'method': 'Wireless (cell phone/other mobile device)', 'issue': 'Privacy', 'city': 'Long Beach', 'state': 'CA', 'zip': '90805', 'location_1': {'latitude': '33.8657', 'longitude': '-118.182006', 'human_address': '{"address": "", "city": "CA", "state": "", "zip": "90805"}'}, ':@computed_region_5ic8_3ue4': '8'}, {'id': '157825', 'ticket_created': '2015-03-02T23:42:06.000Z', 'date_created': '2015-03-02T18:42:06.000', 'issue_type': 'Phone', 'method': 'Wireless (cell phone/other mobile device)', 'issue': 'Availability (including rural call completion)', 'city': 'Galesburg', 'state': 'IL', 'zip': '61401', 'location_1': {'latitude': '40.949292', 'longitude': '-90.379349', 'human_address': '{"address": "", "city": "IL", "state": "", "zip": "61401"}'}, ':@computed_region_5ic8_3ue4': '35'}, {'id': '173077', 'ticket_cr
# ...

# %%
df = pd.read_json(path)

d
# Out:
#          id            ticket_created             date_created issue_type  \
# 0    166574  2015-03-07T07:44:51.000Z  2015-03-07T02:44:51.000   Internet
# 1    100358  2015-01-26T17:51:29.000Z  2015-01-26T12:51:29.000      Phone
# 2    157640  2015-03-02T22:29:49.000Z  2015-03-02T17:29:49.000      Phone
# 3    104244  2015-01-28T17:17:58.000Z  2015-01-28T12:17:58.000      Phone
# 4    153519  2015-02-27T17:49:32.000Z  2015-02-27T12:49:32.000      Phone
# ..      ...                       ...                      ...        ...
# 995  133530  2015-02-16T20:44:32.000Z  2015-02-16T15:44:32.000      Phone
# 996  152900  2015-02-27T02:19:38.000Z  2015-02-26T21:19:38.000      Phone
# 997   14564  2014-11-22T21:20:44.000Z  2014-11-22T16:20:44.000         TV
# 998  138536  2015-02-18T21:30:01.000Z  2015-02-18T16:30:01.000      Phone
# 999   17597  2014-11-29T18:28:01.000Z  2014-11-29T13:28:01.000      Phone
#
#                                         method  \
# ...
